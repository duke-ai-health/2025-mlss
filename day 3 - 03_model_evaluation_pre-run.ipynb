# %% [markdown]
# # 📊 Model Evaluation and Sample Selection with FiftyOne
#
# Welcome to Notebook 3 of our workshop! In this section, we focus on evaluating object detection models, identifying diverse samples, and preparing curated subsets of data using the power of **FiftyOne**.
#
# ## 🚦 What You'll Learn
#
# In this notebook, you will:
#
# - **Apply object detection models** (e.g., YOLOv8 and YOLOv11) to a dataset filtered to include only annotated BDD100K samples.
# - **Compute uniqueness scores** using FiftyOne Brain to identify the most distinct images in your dataset.
# - **Evaluate model predictions** against BDD100K ground truth labels using built-in metrics (e.g., precision, recall).
# - **Filter and clone a view** with the top 100 most unique samples based on their visual or semantic content.
# - **Export this subset** to disk for further analysis, training, or sharing.
#
# ## 🧠 Why This Matters
#
# Evaluating models in a structured and insightful way is essential for improving performance and understanding failure modes. Additionally, selecting a **diverse set of unique images** helps reduce dataset bias and enhances generalization.
#
# This notebook gives you the tools to:
# - Visualize and compare multiple model outputs
# - Select and analyze samples beyond random splits
# - Prepare high-quality, targeted subsets of data
#
# Let’s dive in and explore how FiftyOne empowers data-centric workflows!

# %% [markdown]
# ## 📁 Load the BDD100K Dataset and Launch FiftyOne
# We will use the `BDD100K` dataset from HuggingFace Hub.

# %%
import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.brain as fob

import fiftyone.utils.huggingface as fouh # Hugging Face integration

import os

# Increase both connection and read timeout values (in seconds)
# os.environ["HF_HUB_DOWNLOAD_TIMEOUT"] = "60"  # default is 10
# os.environ["HF_HUB_ETAG_TIMEOUT"] = "30"      # metadata fetch timeout
# dataset = fouh.load_from_hub("dgural/bdd100k", persistent=True, name= "bdd10k") #, overwrite=True)
#fo.delete_dataset("dgural/bdd100k")

# # Define the new dataset name
# dataset_name = "bdd10k"
dataset_name = "bdd10k_imported"

# Check if the dataset exists
if dataset_name in fo.list_datasets():
    print(f"Dataset '{dataset_name}' exists. Loading...")
    dataset = fo.load_dataset(dataset_name)
else:
    print(f"Dataset '{dataset_name}' does not exist. Creating a new one...")
    # Clone the dataset with a new name and make it persistent
    dataset = dataset.clone(dataset_name, persistent=True)
# Out:
# Dataset 'bdd10k_imported' exists. Loading...

# %% [markdown]
# ### 📋 List Available Datasets
# Check which FiftyOne datasets are currently loaded in your environment.

# %%
print(fo.list_datasets())
print(dataset)
# Out:
# ['bdd100k_test', 'bdd10k_imported']
# Name:        bdd10k_imported
# Media type:  image
# Num samples: 10000
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:                 fiftyone.core.fields.ObjectIdField
#     filepath:           fiftyone.core.fields.StringField
#     tags:               fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:           fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:         fiftyone.core.fields.DateTimeField
#     last_modified_at:   fiftyone.core.fields.DateTimeField
#     detections:         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     polylines:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Polylines)
#     weather:            fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     timeofday:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     scene:              fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     drivable:           fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Segmentation)
#     yolo8_predictions:  fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     yolo11_predictions: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     uniqueness:         fiftyone.core.fields.FloatField
#     sklearn_embedding:  fiftyone.core.fields.VectorField

# %% [markdown]
# ### 🚀 Launch FiftyOne App
# Start the FiftyOne App to interactively explore your dataset and model predictions.

# %%
proxy_host = "https://"+os.getenv("VIRTUAL_HOST")+"/fiftyone/"
fo.app_config.proxy_url = proxy_host
session = fo.launch_app(dataset, auto=False )
# Out:
# Connected to FiftyOne on port 5151 at 0.0.0.0.
# If you are not connecting to a remote session, you may need to start a new session and specify a port
# Session launched. Run `session.show()` to open the App in a cell output.

# %%
print(session.url)
# Out:
# https://ml-az-05.oit.duke.edu:40003/fiftyone/?proxy=/fiftyone/&polling=true

# %% [markdown]
# ### 🔧 Setup for Running YOLO Models with FiftyOne
#
# This code snippet does the following:
# - Suppresses Ultralytics logging to keep output clean.
# - Imports the necessary libraries: `fiftyone`, `ultralytics`, and related modules.
# - Loads two YOLO models:
#   - `yolov8s.pt` (YOLOv8 Small)
#   - `yolo11s.pt` (YOLO11 Small, assuming it's a custom or experimental model)

# %%
# # Suppress Ultralytics logging
# import os; os.environ["YOLO_VERBOSE"] = "False"

# import fiftyone as fo
# import fiftyone.zoo as foz
# import fiftyone.utils.ultralytics as fou

# from ultralytics import YOLO

# # YOLOv8
# model1 = YOLO("yolov8s.pt")

# # YOLO11
# model2 = YOLO("yolo11s.pt")
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 387MB/s]
# 100%|███████████████████████████████████████████████████████████████████| 18.4M/18.4M [00:00<00:00, 400MB/s]

# %% [markdown]
# ### 🤖 Apply YOLO Model
# Apply a YOLOv8 or YOLOv11 model to generate predictions on the dataset. Results are stored in the specified label field.

# %%
# dataset.apply_model(model1, label_field="yolo8_predictions")
# dataset.apply_model(model2, label_field="yolo11_predictions")
# Out:
#  100% |█████████████| 10000/10000 [11.1m elapsed, 0s remaining, 15.1 samples/s]
#  100% |█████████████| 10000/10000 [11.5m elapsed, 0s remaining, 14.4 samples/s]

# %% [markdown]
# ### 🧠 Computing Uniqueness with FiftyOne Brain
#
# This snippet uses the FiftyOne Brain module to compute the **uniqueness** score for each sample in the dataset.
# The `compute_uniqueness()` method helps identify how distinct each sample is compared to others, which is useful for:
# - Detecting near-duplicates
# - Selecting diverse subsets
# - Understanding dataset variability

# %%
# import fiftyone.brain as fob

# fob.compute_uniqueness(dataset)
# Out:
# Computing embeddings...
#  100% |█████████████| 10000/10000 [1.5m elapsed, 0s remaining, 113.2 samples/s]
# Computing uniqueness...
# Uniqueness computation complete

# %% [markdown]
# ### 🔍 Inspecting the Dataset with Uniqueness Scores
#
# After computing uniqueness, each sample now includes a `"uniqueness"` field.
# This snippet prints:
# - The entire dataset summary (e.g., number of samples, fields)
# - The first sample, including its new uniqueness score
#
# This is helpful to verify that the uniqueness computation was applied correctly.

# %%
# # Now the samples have a "uniqueness" field on them
# print(dataset)
# print(dataset.first())
# Out:
# Name:        bdd10k
# Media type:  image
# Num samples: 10000
# Persistent:  True
# Tags:        []
# Sample fields:
#     id:                 fiftyone.core.fields.ObjectIdField
#     filepath:           fiftyone.core.fields.StringField
#     tags:               fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:           fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:         fiftyone.core.fields.DateTimeField
#     last_modified_at:   fiftyone.core.fields.DateTimeField
#     detections:         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     polylines:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Polylines)
#     weather:            fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     timeofday:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     scene:              fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     drivable:           fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Segmentation)
#     yolo8_predictions:  fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     yolo11_predictions: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     uniqueness:         fiftyone.core.fields.FloatField
# <Sample: {
#     'id': '66690be9f6be9a28a719fed5',
#     'media_type': 'image',
#     'filepath': '/Users/paularamos/fiftyone/huggingface/hub/dgural/bdd100k/data/b1c66a42-6f7d68ca.jpg',
#     'tags': [],
#     'metadata': <ImageMetadata: {
#         'size_bytes': 53219,
#         'mime_type': 'image/jpeg',
#         'width': 1280,
#         'height': 720,
#         'num_channels': 3,
#     }>,
#     'created_at': datetime.datetime(2024, 6, 12, 2, 46, 1),
#     'last_modified_at': datetime.datetime(2025, 5, 20, 15, 1, 51, 511000),
#     'detections': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645a4',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic sign',
#                 'bounding_box': [
#                     0.7817958921875,
#                     0.39165613194444443,
#                     0.031193851562500007,
#                     0.06238770138888891,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645a5',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic sign',
#                 'bounding_box': [
#                     0.16766694921875,
#                     0.23915285833333333,
#                     0.04679077656250001,
#                     0.07971761805555558,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645a6',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic sign',
#                 'bounding_box': [
#                     0.6229022132812501,
#                     0.4349809236111111,
#                     0.025345003124999987,
#                     0.039858809722222256,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645a7',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic sign',
#                 'bounding_box': [
#                     0.50982450234375,
#                     0.4211169888888889,
#                     0.025345003906249986,
#                     0.017329916666666712,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645a8',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic light',
#                 'bounding_box': [
#                     0.55271604921875,
#                     0.43324793055555555,
#                     0.006823654687500014,
#                     0.02252889305555554,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'G',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645a9',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic light',
#                 'bounding_box': [
#                     0.4893535390625,
#                     0.4107190388888889,
#                     0.007798462500000003,
#                     0.02946085972222221,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'G',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645aa',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic light',
#                 'bounding_box': [
#                     0.24760119296875,
#                     0.4020540805555556,
#                     0.009748078124999981,
#                     0.02426188472222219,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645ab',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic sign',
#                 'bounding_box': [
#                     0.21153330234375,
#                     0.40032108888888884,
#                     0.030219043749999973,
#                     0.01906290833333336,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645ac',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic sign',
#                 'bounding_box': [
#                     0.17254098906249998,
#                     0.41765100555555557,
#                     0.008773270312500015,
#                     0.015596927777777757,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645ad',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.16084329453125,
#                     0.46964075833333335,
#                     0.059463278125000005,
#                     0.06931966805555557,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645ae',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.0370426984375,
#                     0.47830571666666666,
#                     0.0643373171875,
#                     0.07798462916666667,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645af',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.193011953125,
#                     0.47830571666666666,
#                     0.07798462812500002,
#                     0.07105266111111111,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b0',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.0,
#                     0.46790776666666667,
#                     0.0409419296875,
#                     0.09184856111111112,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': True,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b1',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'rider',
#                 'bounding_box': [
#                     0.5078748875,
#                     0.49216965,
#                     0.010722886718750057,
#                     0.03812581805555561,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b2',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'motorcycle',
#                 'bounding_box': [
#                     0.50690007890625,
#                     0.5094995694444445,
#                     0.011697695312500044,
#                     0.02946085694444444,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b3',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic light',
#                 'bounding_box': [
#                     0.5566152796875,
#                     0.46790776666666667,
#                     0.010722886718749968,
#                     0.02252889305555554,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b4',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5341946992187501,
#                     0.4956356319444445,
#                     0.02924423593749994,
#                     0.05025675972222222,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b5',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.551741240625,
#                     0.5060335819444445,
#                     0.021445773437500027,
#                     0.03639282777777776,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b6',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.56831297421875,
#                     0.5077665763888889,
#                     0.026319811718749975,
#                     0.048523769444444455,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b7',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5848847078125,
#                     0.5025676,
#                     0.04679077656250001,
#                     0.06585368611111109,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b8',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.61510375078125,
#                     0.497368625,
#                     0.09260674531249995,
#                     0.09358155416666665,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645b9',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.68723953125,
#                     0.5216305097222222,
#                     0.06238770234375002,
#                     0.10571249444444446,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645ba',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.7299653148116186,
#                     0.46516093399921654,
#                     0.2154325335937501,
#                     0.20622601666666673,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645bb',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.94068957109375,
#                     0.5770862458333333,
#                     0.05848847109374997,
#                     0.15943523888888894,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': True,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645bc',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic light',
#                 'bounding_box': [
#                     0.47083218984375,
#                     0.4731067416666667,
#                     0.005848846875000024,
#                     0.017329918055555518,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'G',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645bd',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic light',
#                 'bounding_box': [
#                     0.46205891875000005,
#                     0.4557768236111111,
#                     0.004874039062499946,
#                     0.019062909722222247,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'G',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645be',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'traffic light',
#                 'bounding_box': [
#                     0.4133185265625,
#                     0.46097579861111115,
#                     0.005848846874999936,
#                     0.013863934722222224,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'G',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645bf',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.43086506796875,
#                     0.49390264166666664,
#                     0.010722885937499971,
#                     0.017329918055555598,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645c0',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.44841161015625,
#                     0.4887036666666667,
#                     0.009748078124999981,
#                     0.02426188472222219,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645c1',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.45426045703125,
#                     0.4956356319444445,
#                     0.012672501562499949,
#                     0.02946085972222221,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645c2',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.46595814999999996,
#                     0.4887036666666667,
#                     0.031193851562500007,
#                     0.046790776388888844,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': False,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645c3',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.40454525625000004,
#                     0.49390264166666664,
#                     0.013647309374999939,
#                     0.017329918055555598,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645c4',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.39187275390625,
#                     0.4956356319444445,
#                     0.012672502343750036,
#                     0.019062909722222167,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#             <Detection: {
#                 'id': '66690bccf6be9a28a71645c5',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.3538552484375,
#                     0.49043665694444444,
#                     0.02047096406250004,
#                     0.02772786944444445,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'occluded': True,
#                 'truncated': False,
#                 'trafficLightColor': 'NA',
#             }>,
#         ],
#     }>,
#     'polylines': <Polylines: {
#         'polylines': [
#             <Polyline: {
#                 'id': '66690bccf6be9a28a71645c6',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'direct',
#                 'points': [
#                     [
#                         [0.18839347265625, 0.9693381291666666],
#                         [0.42306660546875, 0.5285624763888889],
#                         [0.456210071875, 0.5250964930555556],
#                         [0.7500271523437501, 0.9402163833333332],
#                         [0.5593057156250001, 0.9235753861111111],
#                         [0.38379518984375, 0.9235753861111111],
#                         [0.18839347265625, 0.9693381291666666],
#                     ],
#                 ],
#                 'confidence': None,
#                 'index': None,
#                 'closed': True,
#                 'filled': True,
#                 'areaType': 'direct',
#             }>,
#             <Polyline: {
#                 'id': '66690bccf6be9a28a71645c7',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'alternative',
#                 'points': [
#                     [
#                         [0.771088415625, 0.9485368819444444],
#                         [0.484421225, 0.5512330569444445],
#                         [0.5323941015625, 0.5449926819444444],
#                         [1.0004099921875, 0.7883672763888889],
#                         [1.0004099921875, 0.9693381291666666],
#                         [0.771088415625, 0.9485368819444444],
#                     ],
#                 ],
#                 'confidence': None,
#                 'index': None,
#                 'closed': True,
#                 'filled': True,
#                 'areaType': 'alternative',
#             }>,
#         ],
#     }>,
#     'weather': <Classification: {
#         'id': '66690bccf6be9a28a71645c8',
#         'tags': [],
#         'label': 'overcast',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'timeofday': <Classification: {
#         'id': '66690bccf6be9a28a71645c9',
#         'tags': [],
#         'label': 'daytime',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'scene': <Classification: {
#         'id': '66690bccf6be9a28a71645ca',
#         'tags': [],
#         'label': 'city street',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'drivable': <Segmentation: {
#         'id': '66690bccf6be9a28a71645cb',
#         'tags': [],
#         'mask': None,
#         'mask_path': '/Users/paularamos/fiftyone/huggingface/hub/dgural/bdd100k/fields/drivable/b1c66a42-6f7d68ca.png',
#     }>,
#     'yolo8_predictions': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734f8',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.18884247541427612,
#                     0.4808044172823429,
#                     0.0826762318611145,
#                     0.06923573464155197,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8823796510696411,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734f9',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'truck',
#                 'bounding_box': [
#                     0.7333610504865646,
#                     0.4691103398799896,
#                     0.2104145586490631,
#                     0.20365804433822632,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8608505129814148,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734fa',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.618583083152771,
#                     0.5019387379288673,
#                     0.08692646026611328,
#                     0.09077148139476776,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8202077150344849,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734fb',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.9411096572875977,
#                     0.5776556134223938,
#                     0.058327674865722656,
#                     0.15285229682922363,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.7803612351417542,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734fc',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.00010384432971477509,
#                     0.47016624361276627,
#                     0.03886609524488449,
#                     0.08778135478496552,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.771416187286377,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734fd',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.0373988151550293,
#                     0.4827479086816311,
#                     0.06294436752796173,
#                     0.07032538205385208,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.7077423334121704,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734fe',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.688786530867219,
#                     0.5272166132926941,
#                     0.053560446947813034,
#                     0.09347975254058838,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6857737898826599,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af499734ff',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5977373011410236,
#                     0.512841060757637,
#                     0.0333036407828331,
#                     0.056227535009384155,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6246188282966614,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973500',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.15906024910509586,
#                     0.4758686311542988,
#                     0.037436556071043015,
#                     0.05620863288640976,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.5729254484176636,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973501',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5341899869963527,
#                     0.5004076641052961,
#                     0.026802444830536842,
#                     0.04362589493393898,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.5428534150123596,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973502',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.15966677106916904,
#                     0.47441836819052696,
#                     0.0511593334376812,
#                     0.057620830833911896,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.47893524169921875,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973503',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.570662260055542,
#                     0.5079624988138676,
#                     0.02085590362548828,
#                     0.052741579711437225,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.43934687972068787,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973504',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5532159805297852,
#                     0.5076138619333506,
#                     0.020743370056152344,
#                     0.04181976243853569,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.4343298673629761,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973505',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5412147641181946,
#                     0.5007701646536589,
#                     0.03015613555908203,
#                     0.04569074884057045,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3785572350025177,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973506',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.4676607009023428,
#                     0.49538165517151356,
#                     0.026144791394472122,
#                     0.036118146032094955,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3628864586353302,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c93b9cd0f07af49973507',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5838593244552612,
#                     0.5097358450293541,
#                     0.02490711212158203,
#                     0.05643327534198761,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.35597464442253113,
#                 'index': None,
#             }>,
#         ],
#     }>,
#     'yolo11_predictions': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '682c9650cd0f07af4998771b',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.18753034621477127,
#                     0.48085200041532516,
#                     0.08342413604259491,
#                     0.06661953032016754,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8368844389915466,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af4998771c',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.0003032144159078598,
#                     0.47031208500266075,
#                     0.039838165044784546,
#                     0.0870937779545784,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.775312066078186,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af4998771d',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.6177873834967613,
#                     0.49976326525211334,
#                     0.0888025313615799,
#                     0.0962660014629364,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.7610337138175964,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af4998771e',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.9416765458881855,
#                     0.5789752677083015,
#                     0.057787321507930756,
#                     0.15108464658260345,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.7546641230583191,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af4998771f',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'truck',
#                 'bounding_box': [
#                     0.7315610647201538,
#                     0.4665202796459198,
#                     0.21083950996398926,
#                     0.20403510332107544,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.7404492497444153,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987720',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.6890208963304758,
#                     0.5242578461766243,
#                     0.05297679826617241,
#                     0.10089407861232758,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6855867505073547,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987721',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.15913711115717888,
#                     0.47639420442283154,
#                     0.03990814834833145,
#                     0.05727488175034523,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.5997182130813599,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987722',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5965869780629873,
#                     0.5100919902324677,
#                     0.03637056425213814,
#                     0.061247169971466064,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.5325644016265869,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987723',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.03752898424863815,
#                     0.4793698415160179,
#                     0.0626097172498703,
#                     0.07390137016773224,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.48563462495803833,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987724',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5358647350221872,
#                     0.4994427412748337,
#                     0.03458709642291069,
#                     0.04768863320350647,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.39682987332344055,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987725',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.569299578666687,
#                     0.5062849335372448,
#                     0.0223846435546875,
#                     0.05577019602060318,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.38432198762893677,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987726',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.5817628148943186,
#                     0.5050438828766346,
#                     0.026738356798887253,
#                     0.06205054372549057,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3603168725967407,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '682c9650cd0f07af49987727',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'car',
#                 'bounding_box': [
#                     0.573467468842864,
#                     0.5045958738774061,
#                     0.03161125257611275,
#                     0.060106996446847916,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3001193702220917,
#                 'index': None,
#             }>,
#         ],
#     }>,
#     'uniqueness': 0.29123670678445246,
# }>

# %% [markdown]
# ### 📊 Viewing Least Unique Samples in FiftyOne App
#
# This code sorts the dataset by the `"uniqueness"` field in **descending order**, so the **least unique** (most similar or duplicated) samples appear first.
#
# - `sort_by("uniqueness", reverse=True)`: sorts samples from least to most unique.
# - `session.view = dups_view`: opens this sorted view in the FiftyOne App for interactive exploration.
#
# Great for spotting near-duplicates or redundant data!

# %%
# Sort in increasing order of uniqueness (least unique first)
dups_view = dataset.sort_by("uniqueness", reverse=True)

# Open view in the App
session.view = dups_view

# %% [markdown]
# ### 🌟 Creating a View of the Top 100 Most Unique Samples
#
# This code generates a new view containing the **100 most unique samples** in the dataset:
#
# - `sort_by("uniqueness", reverse=True)`: sorts the dataset from most to least unique.
# - `.limit(100)`: selects only the top 100 samples.
#
# Useful for exploring diverse samples or building a representative subset for training or analysis.

# %%
# Create a view with the 100 most unique samples
unique_view = dataset.sort_by("uniqueness", reverse=True).limit(100)

# %% [markdown]
# ### 📦 Cloning and Exporting the Unique Samples Dataset
#
# **Step 3:**
# Clone the `unique_view` as a standalone dataset named `"bdd100k_100_unique"`.
# This creates a new `fiftyone.core.dataset.Dataset` object that can be manipulated or exported independently.
#
# **Step 4:**
# Export the cloned dataset to disk using FiftyOne’s export functionality:
# - `export_dir`: defines the output directory (`bdd100k_unique_100_FO`)
# - `dataset_type`: specifies the export format (in this case, `FiftyOneDataset`, but this can be changed to COCO, YOLO, etc.)
#
# Ideal for saving a diverse subset for further use or sharing.

# %%
# # Clone the view as a standalone dataset
# unique_dataset = unique_view.clone(name="bdd100k_100_unique")
# unique_dataset.persistent=True

# # Export the dataset (can be modified to your desired format or directory)
# export_dir = "bdd100k_unique_100_FO"
# unique_dataset.export(
#     export_dir=export_dir,
#     dataset_type=fo.types.FiftyOneDataset,
# )

# %%
# if "bdd100k_100_unique" in fo.list_datasets():
#     fo.delete_dataset("bdd100k_100_unique")

# %%
# # Define the new dataset name
dataset_name = "bdd100k_100_unique"

# Check if the dataset exists
if dataset_name in fo.list_datasets():
    print(f"Dataset '{dataset_name}' exists. Loading...")
    unique_dataset = fo.load_dataset(dataset_name)
else:
    print(f"Dataset '{dataset_name}' does not exist. Creating a new one...")
    # Path to the exported folder
    export_dir = "bdd100k_unique_100_FO"
    
    # Load the dataset from the folder
    unique_dataset = fo.Dataset.from_dir(
        dataset_dir=export_dir,
        dataset_type=fo.types.FiftyOneDataset,
        name=dataset_name  # You can choose any name here
    )
    
unique_dataset.persistent = True
# Out:
# Dataset 'bdd100k_100_unique' does not exist. Creating a new one...
# Importing samples...
#  100% |█████████████████| 100/100 [17.7ms elapsed, 0s remaining, 5.7K samples/s]

# %%
session = fo.launch_app(unique_dataset, auto=False )
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.

# %% [markdown]
# ### 🧠 Comparing Similarity Across Images and YOLO Detections
#
# We now compute similarity in three dimensions:
# 1. **Image-level similarity** using CLIP embeddings (already precomputed).
# 2. **Detection-level similarity with YOLOv8 results.**
# 3. **Detection-level similarity with YOLOv11 results.**
#
# By using `patches_field`, we compare how similar individual object detections are across images. This enables us to:
# - Group images with visually or semantically similar detections.
# - Evaluate model differences between YOLOv8 and YOLOv11.
# - Identify edge cases or inconsistencies in object detection.
#
# Each similarity computation is stored with a different `brain_key` and can be visualized interactively using FiftyOne's App.

# %%
# # Step 1: Define the field where YOLO8 and YOLO11 detections are stored
# # Adjust these names to your actual label field names
# yolo8_field = "yolo8_predictions"
# yolo11_field = "yolo11_predictions"

# # Example 1: Similarity based on images (already computed with embeddings)
# fob.compute_visualization(
#     unique_dataset,
#     brain_key="image_similarity"
# )

# # Example 2: Similarity based on YOLOv8 detections
# fob.compute_visualization(
#     unique_dataset,
#     brain_key="yolo8_similarity",
#     patches_field=yolo8_field
# )

# # Example 3: Similarity based on YOLOv11 detections
# fob.compute_visualization(
#     unique_dataset,
#     brain_key="yolo11_similarity",
#     patches_field=yolo11_field
# )
# Out:
# Computing embeddings...
#  100% |█████████████████| 100/100 [15.0s elapsed, 0s remaining, 6.6 samples/s]
# Generating visualization...
# /Users/paularamos/Documents/GitHub/awesome-fiftyone/DB_Mosaic_AI_FiftyOne/fiftyone_DB_env/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# UMAP( verbose=True)
# Wed May 28 07:02:57 2025 Construct fuzzy simplicial set
# Wed May 28 07:02:57 2025 Finding Nearest Neighbors
# Wed May 28 07:02:58 2025 Finished Nearest Neighbor Search
# Wed May 28 07:02:59 2025 Construct embedding
# Epochs completed: 100%| ██████████ 500/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Wed May 28 07:03:00 2025 Finished embedding
# Computing patch embeddings...
#    0% ||----------------|   0/100 [14.6ms elapsed, ? remaining, ? samples/s]
#  100% |█████████████████| 100/100 [57.7s elapsed, 0s remaining, 1.8 samples/s]
# Generating visualization...
# UMAP( verbose=True)
# Wed May 28 07:03:58 2025 Construct fuzzy simplicial set
# /Users/paularamos/Documents/GitHub/awesome-fiftyone/DB_Mosaic_AI_FiftyOne/fiftyone_DB_env/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Wed May 28 07:03:58 2025 Finding Nearest Neighbors
# Wed May 28 07:03:58 2025 Finished Nearest Neighbor Search
# Wed May 28 07:03:58 2025 Construct embedding
# Epochs completed: 100%| ██████████ 500/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Wed May 28 07:03:58 2025 Finished embedding
# Computing patch embeddings...
#  100% |█████████████████| 100/100 [53.9s elapsed, 0s remaining, 2.0 samples/s]
# Generating visualization...
# UMAP( verbose=True)
# Wed May 28 07:04:52 2025 Construct fuzzy simplicial set
# /Users/paularamos/Documents/GitHub/awesome-fiftyone/DB_Mosaic_AI_FiftyOne/fiftyone_DB_env/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Wed May 28 07:04:52 2025 Finding Nearest Neighbors
# Wed May 28 07:04:52 2025 Finished Nearest Neighbor Search
# Wed May 28 07:04:52 2025 Construct embedding
# Epochs completed: 100%| ██████████ 500/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Wed May 28 07:04:52 2025 Finished embedding

# %% [markdown]
# ### 🚀 Launch FiftyOne App
# Start the FiftyOne App to interactively explore your dataset and model predictions.

# %%
# session = fo.launch_app(unique_dataset, auto=False)
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.

# %% [markdown]
# ### 🧩 Introduction to FiftyOne Plugins
#
# **FiftyOne Plugins** extend the capabilities of the FiftyOne App by adding custom panels, tools, and workflows tailored to your dataset and model needs.
#
# Plugins allow you to:
# - Visualize custom metrics and evaluation results
# - Add new buttons, filters, or visual tools to the App interface
# - Seamlessly integrate external libraries or logic into the FiftyOne experience
#
# They are built using JavaScript and Python and follow a modular architecture that makes them easy to download, install, and use.
#
# ---
#
# ### 🔌 Downloading the `@voxel51/evaluation` Plugin
#
# The following command downloads a specific plugin from the official [Voxel51 plugin repository](https://github.com/voxel51/fiftyone-plugins):
#
# ```python
# !fiftyone plugins download https://github.com/voxel51/fiftyone-plugins --plugin-names @voxel51/evaluation

# %%
# !fiftyone plugins download https://github.com/voxel51/fiftyone-plugins --plugin-names @voxel51/evaluation

# %% [markdown]
# ### 📊 Evaluate Detections
# Run evaluation between model predictions and ground truth labels using FiftyOne's built-in metrics.

# %%
# # eval_key
# evalkey_yolo8 = "evalkey_yolo8_"
# evalkey_yolo11 = "evalkey_yolo11_"

# # Detection evaluation
# unique_dataset.evaluate_detections(
#     "yolo8_predictions",
#     gt_field="detections",
#     eval_key=evalkey_yolo8,
# )

# # Detection evaluation
# unique_dataset.evaluate_detections(
#     "yolo11_predictions",
#     gt_field="detections",
#     eval_key=evalkey_yolo11,
# )
# Out:
# Evaluating detections...
#  100% |█████████████████| 100/100 [2.2s elapsed, 0s remaining, 39.6 samples/s]
# Evaluating detections...
#  100% |█████████████████| 100/100 [2.3s elapsed, 0s remaining, 39.2 samples/s]

# %%
# export_dir = "bdd100k_FO"
# dataset.export(
#     export_dir=export_dir,
#     dataset_type=fo.types.FiftyOneDataset,
# )
# Out:
# Exporting samples...
#  100% |████████████████| 10000/10000 [11.0s elapsed, 0s remaining, 942.4 docs/s]

# %%
# # Step 4: Export the dataset (can be modified to your desired format or directory)
# export_dir = "bdd100k_unique_100_FO"
# unique_dataset.export(
#     export_dir=export_dir,
#     dataset_type=fo.types.FiftyOneDataset,
# )
# Out:
# Exporting samples...
#  100% |████████████████████| 100/100 [119.4ms elapsed, 0s remaining, 837.4 docs/s]
